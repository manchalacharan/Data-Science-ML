# %% [markdown]
# # ![download.png](attachment.download.png)

# %% [markdown]
# https://www.mathsisfun.com/

# %% [markdown]
# # The cost function

# %% [markdown]
# ##    $$ f(x,y) = \frac{1} {3^{-x^2-y^2}+1}$$

# %%
$$ f(x,y) = \frac{1} {3^{-x^2-y^2}+1}$$      ######top function display  program

# %% [markdown]
# # Partial Derivatives

# %% [markdown]
# ## $$ \frac{\partial f}{\partial x} = \frac{2x \ln(3) \cdot 3^{-x^2 - y^2}}{\left(3^{-x^2 - y^2} + 1\right) ^2}$$
# ## $$ \frac{\partial f}{\partial y} = \frac{2y \ln(3) \cdot 3^{-x^2 - y^2}}{\left(3^{-x^2 - y^2} + 1\right) ^2}$$

# %%
$$ \frac{\partial f}{\partial x} = \frac{2x \ln(3) \cdot 3^{-x^2 - y^2}}{\left(3^{-x^2 - y^2} + 1\right) ^2}$$   #top function display  program
$$ \frac{\partial f}{\partial y} = \frac{2y \ln(3) \cdot 3^{-x^2 - y^2}}{\left(3^{-x^2 - y^2} + 1\right) ^2}$$   #top function display  program

# %% [markdown]
# https://www.symbolab.com/

# %% [markdown]
# ##    $$ f(x,y) = \frac{1} {3^{-x^2-y^2}+1}$$

# %% [markdown]
# ## $$ f(x,y) = \frac{1} {r+1}$$

# %% [markdown]
# ## Where $ r $ is  $3^{-x^2-y^2}$

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # cm means colormap
from math import log

# %%
def f(x,y):
    
    r = 3**(-x**2 - y**2)
    
    return 1/(r+1)

# %%
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

# %%
x_4, y_4 = np.meshgrid(x_4, y_4)

# %%
x_4.shape
# Out:
# (200, 200)

# %%
y_4.shape
# Out:
# (200, 200)

# %%
fig=plt.figure(figsize=(16, 12))

ax = fig.gca(projection = '3d')

ax.set_xlabel('X', fontsize=20)

ax.set_ylabel('Y', fontsize=20)

ax.set_zlabel('f(x, y) - Cost', fontsize=20)

plt.show()
# Out:
# C:\Users\manch\AppData\Local\Temp/ipykernel_1180/44392832.py:3: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection = '3d')

# %%
fig=plt.figure(figsize=(15, 11))

ax = fig.gca(projection = '3d')

ax.set_xlabel('X', fontsize=20)

ax.set_ylabel('Y', fontsize=20)

ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), alpha = 0.4, cmap = cm.coolwarm )

plt.show()
# Out:
# C:\Users\manch\AppData\Local\Temp/ipykernel_1180/4150681055.py:3: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection = '3d')

# %% [markdown]
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
# Gradient Descent...
# Partial derivatives...

# %% [markdown]
# ## Partial Derivatives

# %% [markdown]
# # $$ \frac{\partial f}{\partial x} = \frac{2x \ln(3) \cdot 3^{-x^2 - y^2}}{\left(3^{-x^2 - y^2} + 1\right) ^2}$$

# %% [markdown]
# # $$ \frac{\partial f}{\partial y} = \frac{2y \ln(3) \cdot 3^{-x^2 - y^2}}{\left(3^{-x^2 - y^2} + 1\right) ^2}$$

# %%
# covert the PD's....into python functions...

# %%
def fpx(x, y):
    
    
    r = 3**(-x**2 - y**2)
        
    return  2*x*log(3)*r / (r +1)**2

# %%
def fpy(x, y):
    
    
    r = 3**(-x**2 - y**2)
        
    return  2*y*log(3)*r / (r +1)**2

# %%
params = np.array([1.8,  1.0])

max_iter = 1000

multiplier = 0.1

for n in range(max_iter):
    
    gradient_x = fpx(params[0], params[1])
    
    gradient_y = fpy(params[0], params[1])
    
    gradients = np.array([gradient_x, gradient_y])
          
    params = params - multiplier *  gradients

# %%
print('Values in gradient array', gradients)
# Out:
# Values in gradient array [1.08410585e-23 6.02281029e-24]

# %%
print('Minimum occurs at x value of: ', params[0])
# Out:
# Minimum occurs at x value of:  1.865180758685096e-23

# %%
print('Minimum occurs at y value of: ', params[1])
# Out:
# Minimum occurs at y value of:  1.0362115326028303e-23

# %%
print('The cost is: ', f(params[0], params[1]))
# Out:
# The cost is:  0.5

# %%
# Plotting the GD on the Surface

# %%
params = np.array([1.8,  1.0])

max_iter = 1000

multiplier = 0.1

values_array = params.reshape(1,2)

for n in range(max_iter):
    
    gradient_x = fpx(params[0], params[1])
    
    gradient_y = fpy(params[0], params[1])
    
    gradients = np.array([gradient_x, gradient_y])
          
    params = params - multiplier *  gradients
    
    values_array = np.append(values_array, params.reshape(1,2), axis = 0)

# %%
fig=plt.figure(figsize=(15, 11))

ax = fig.gca(projection = '3d')

ax.set_xlabel('X', fontsize=20)

ax.set_ylabel('Y', fontsize=20)

ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f(x_4, y_4), alpha = 0.4, cmap = cm.coolwarm )

ax.scatter(values_array[:,0], values_array[:,1], f(values_array[:,0], values_array[:,1]), color = 'red', s = 20)

plt.show()
# Out:
# C:\Users\manch\AppData\Local\Temp/ipykernel_1180/3211285618.py:3: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection = '3d')

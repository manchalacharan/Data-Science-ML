# %% [markdown]
# # Learning rate demonstration

# %% [markdown]
# # $$g(x)=x^4-4x^2+5$$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x**4 - 4*x**2 + 5

def dg(x):
    return 4*x**3 - 8*x

# %%
def gradient_descent( initial_guess,  multiplier, precision, max_iter):
    
    
    new_x = initial_guess
    
    x_list = [new_x]
    
    slope_list = [dg(new_x)]

    for n in range(max_iter):
        
        previous_x = new_x 
        
        new_x = previous_x - multiplier * dg(previous_x)
        
        step_size = abs(new_x - previous_x)
        
        x_list.append(new_x)
        
        slope_list.append(dg(new_x))
        

        if step_size < precision:
            
            break
            
    return new_x, x_list, slope_list

# %%
n = 100
local_min, list_x, deriv_list = gradient_descent(initial_guess=1.9, multiplier = 0.25, precision =0.0001, max_iter = n)

# %%
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.grid()
plt.xlim(-2,2)
plt.ylim(-0.5, 6.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.5)
plt.scatter(list_x, g(np.array(list_x)), color='green', s=100, alpha=0.9)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()
   
print('Number of steps:', len(list_x))
print('Local min occurs at:', local_min)
# Out:
# Number of steps: 101
# Local min occurs at: -1.9684400420244323

# %% [markdown]
# # multiplier or learning rate or gamma = 0.0001

# %%
n = 100

local_min, list_x_1, deriv_list = gradient_descent(initial_guess=3, multiplier = 0.0001, precision =0.0001, max_iter = n)

# %%
plt.figure(figsize=[20, 10])

plt.xlim(0, n)

plt.ylim(0, 50)

plt.title('Effect of the learning rate 1', fontsize=17)

plt.xlabel('Nr of iterations', fontsize=16)

plt.ylabel('Cost', fontsize=16) # X Axis Data: will have the number of iterations from  0 to n+1

iteration_list = list(range(0, n+1))

plt.plot(iteration_list, g(np.array(list_x_1)), color='pink', linewidth=5)

plt.scatter(iteration_list, g(np.array(list_x_1)), color='red', s=80)

# plt.plot(iteration_list, g(np.array(list_x_1)), color='pink', linewidth=5)

print('ITERATION LIST:',  len (iteration_list),     '.......LIST OF X\'s:', len(list_x_1),'.... MIN IS AT', list_x_1[100])

plt.show()
# Out:
# ITERATION LIST: 101 .......LIST OF X's: 101 .... MIN IS AT 2.433817327606845

# %%
g(2.433817327606845) # value of the cost with the given gamma after 101 iterations( 100+1)
# Out:
# 16.393591606401515

# %% [markdown]
# # multiplier or learning rate or gamma = 0.001

# %%
n = 100

local_min, list_x_2, deriv_list = gradient_descent(initial_guess=3, multiplier = 0.001, precision =0.0001, max_iter = n)

# %%
plt.figure(figsize=[20, 10])

plt.xlim(0, n)

plt.ylim(0, 50)

plt.title('Effect of the learning rate 2', fontsize=17)

plt.xlabel('Nr of iterations', fontsize=16)

plt.ylabel('Cost', fontsize=16)

# X Axis Data: will have the number of iterations from  0 to n+1

iteration_list = list(range(0, n+1))

plt.plot(iteration_list, g(np.array(list_x_2)), color='green', linewidth=5)

plt.scatter(iteration_list, g(np.array(list_x_2)), color='green', s=80, alpha =0.9)

plt.show()

print('ITERATION LIST:',  len (iteration_list),     '.......LIST OF X\'s:', len(list_x_2), '.... MIN IS AT', list_x_2[100])
# Out:
# ITERATION LIST: 101 .......LIST OF X's: 101 .... MIN IS AT 1.5361689393503988

# %%
g(1.5361689393503988) # value of the cost with the given gamma after 101 iterations( 100+1)
# Out:
# 1.1294668415831657

# %% [markdown]
# # multiplier or learning rate or gamma = 0.0002

# %%
n = 100

local_min, list_x_3, deriv_list = gradient_descent(initial_guess=3, multiplier = 0.0002, precision =0.0001, max_iter = n)

# %%
plt.figure(figsize=[20, 10])

plt.xlim(0, n)

plt.ylim(0, 50)

plt.title('Effect of the learning rate 3', fontsize=17)

plt.xlabel('Nr of iterations', fontsize=16)

plt.ylabel('Cost', fontsize=16)

# X Axis Data: will have the number of iterations from  0 to n+1

iteration_list = list(range(0, n+1))

plt.plot(iteration_list, g(np.array(list_x_3)), color='blue', linewidth=5)

plt.scatter(iteration_list, g(np.array(list_x_3)), color='blue', s=80, alpha =0.9)

plt.show()

print('ITERATION LIST:',  len (iteration_list),     '.......LIST OF X\'s:', len(list_x_3),'.... MIN IS AT', list_x_3[100])
# Out:
# ITERATION LIST: 101 .......LIST OF X's: 101 .... MIN IS AT 2.140717830935688

# %%
g(2.140717830935688) # value of the cost with the given gamma after 101 iterations( 100+1)
# Out:
# 7.67019895552896

# %% [markdown]
# # multiplier or learning rate or gamma = 0.25

# %%
n = 100

local_min, list_x_4, deriv_list = gradient_descent(initial_guess=1.9, multiplier = 0.25, precision =0.0001, max_iter = n)

# %%
plt.figure(figsize=[20, 10])

plt.xlim(0, n)

plt.ylim(0, 50)

plt.title('Effect of the learning rate 4', fontsize=17)

plt.xlabel('Nr of iterations', fontsize=16)

plt.ylabel('Cost', fontsize=16)

# X Axis Data: will have the number of iterations from  0 to n+1

iteration_list = list(range(0, n+1))

plt.plot(iteration_list, g(np.array(list_x_4)), color='black', linewidth=5)

plt.scatter(iteration_list, g(np.array(list_x_4)), color='red', s=80, )

plt.show()

print('ITERATION LIST:',  len (iteration_list),     '.......LIST OF X\'s:', len(list_x_4), 'MIN IS AT', list_x_4[100])
# Out:
# ITERATION LIST: 101 .......LIST OF X's: 101 MIN IS AT -1.9684400420244323

# %%
n = 100

# function called for different values of learning rate, initial guess etc
local_min, list_x_1, deriv_list = gradient_descent(initial_guess=3, multiplier = 0.0001, precision =0.0001, max_iter = n)

local_min, list_x_2, deriv_list = gradient_descent(initial_guess=3, multiplier = 0.001, precision =0.0001, max_iter = n)

local_min, list_x_3, deriv_list = gradient_descent(initial_guess=3, multiplier = 0.0002, precision =0.0001, max_iter = n) 

local_min, list_x_4, deriv_list = gradient_descent(initial_guess=1.9, multiplier = 0.25, precision =0.0001, max_iter = n)



plt.figure(figsize=[20, 10])


# Lims and Titles....
plt.xlim(0, n)
plt.ylim(0, 50)
plt.title('Effect of the learning rate...All combined', fontsize=17)
plt.xlabel('Nr of iterations', fontsize=16)
plt.ylabel('Cost', fontsize=16)

# X Axis Data: will have the number of iterations from  0 to n+1
iteration_list = list(range(0, n+1))

# plots 1 ......
plt.plot(iteration_list, g(np.array(list_x_1)), color='pink', linewidth=5)
plt.scatter(iteration_list, g(np.array(list_x_1)), color='red', s=80)
# plots 2 .....
plt.plot(iteration_list, g(np.array(list_x_2)), color='green', linewidth=5)
plt.scatter(iteration_list, g(np.array(list_x_2)), color='green', s=80, alpha =0.9)
# plot 3 .....
plt.plot(iteration_list, g(np.array(list_x_3)), color='blue', linewidth=5)
plt.scatter(iteration_list, g(np.array(list_x_3)), color='blue', s=80, alpha =0.9)
# plot 4.......
plt.plot(iteration_list, g(np.array(list_x_4)), color='black', linewidth=5, alpha = .9)
plt.scatter(iteration_list, g(np.array(list_x_4)), color='red', s=80)





plt.show()
